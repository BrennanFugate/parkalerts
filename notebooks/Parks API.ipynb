# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import urllib.request, json
from datetime import date
import tkinter as tk

# %%
# Tennessee
endpoint = "https://developer.nps.gov/api/v1/parks?stateCode=tn"
HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
req = urllib.request.Request(endpoint,headers=HEADERS)

response = urllib.request.urlopen(req).read()
response
# Out:
# b' \r\n{\r\n\r\n"total":"15",\r\n"limit":"50",\r\n"start":"0",  \r\n"data":[\r\n\r\n{\r\n\r\n"id":"2ED6E071-57AA-4B08-8DDA-5CB09FBB75C8"\r\n\r\n,"url":\r\n\r\n"https://www.nps.gov/anjo/index.htm"\r\n\r\n,"fullName":"Andrew Johnson National Historic Site"      \r\n\r\n,"parkCode":"anjo"\r\n\r\n,"description":"Andrew Johnson\'s complex presidency (1865-69) illustrates the Constitution at work following the Civil War. As the President and Congress disagreed on Reconstruction methods, the Constitution served as their guide on balance of powers, vetoes, and impeachment. In the end, it evolved as a living document with pivotal amendments on freedom, citizenship, and voting rights - topics still vital today."\r\n\r\n,"latitude":\r\n\r\n"36.15624509" \r\n\r\n,"longitude":\r\n\r\n"-82.83709021" \r\n\r\n,"latLong":"lat:36.15624509, long:-82.83709021"\r\n\r\n,"activities":[{"id":"09DF0950-D319-4557-A57E-04CD2F63FF42","name":"Arts and Culture"},{"id":"B33DC9B6-0B7D-4322-BAD7-A13A34C584A3","name"
# ...

# %%
# Acadia National Park
park = "acad"
parkendpoint = "https://developer.nps.gov/api/v1/parks?parkCode=" + park + "&fields=addresses"
HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
parkreq = urllib.request.Request(parkendpoint,headers=HEADERS)
parkresponse = urllib.request.urlopen(parkreq).read()
acadiadata = json.loads(parkresponse.decode('utf-8'))
acadiadata

    

    ### Prepare and execute output
##for park in listdata["data"]:
    #print(park["fullName"])


##response = urllib.request.urlopen(req).read()
##data = json.loads#(response.decode('utf-8'))
# Out:
# {'total': '1',
#  'limit': '50',
#  'start': '0',
#  'data': [{'id': '6DA17C86-088E-4B4D-B862-7C1BD5CF236B',
#    'url': 'https://www.nps.gov/acad/index.htm',
#    'fullName': 'Acadia National Park',
#    'parkCode': 'acad',
#    'description': "Acadia National Park protects the natural beauty of the highest rocky headlands along the Atlantic coastline of the United States, an abundance of habitats, and a rich cultural heritage. At 4 million visits a year, it's one of the top 10 most-visited national parks in the United States. Visitors enjoy 27 miles of historic motor roads, 158 miles of hiking trails, and 45 miles of carriage roads.",
#    'latitude': '44.409286',
#    'longitude': '-68.247501',
#    'latLong': 'lat:44.409286, long:-68.247501',
#    'activities': [{'id': '09DF0950-D319-4557-A57E-04CD2F63FF42',
#      'name': 'Arts and Culture'},
#     {'id': 'FAED7F97-3474-4C21-AB42-FB0768A2F826',
#      'name': 'Cultural Demonstrations'},
# ...

# %%
for desc in acadiadata["data"]:
    print(desc["description"])
# Out:
# Acadia National Park protects the natural beauty of the highest rocky headlands along the Atlantic coastline of the United States, an abundance of habitats, and a rich cultural heritage. At 4 million visits a year, it's one of the top 10 most-visited national parks in the United States. Visitors enjoy 27 miles of historic motor roads, 158 miles of hiking trails, and 45 miles of carriage roads.

# %%
# Configure API request
# Note limit parameter is arbitrary value greater than total number of NPS sites
listendpoint = "https://developer.nps.gov/api/v1/parks?limit=600"
req = urllib.request.Request(listendpoint,headers=HEADERS)

# Execute request and parse response
listresponse = urllib.request.urlopen(req).read()
listdata = json.loads(listresponse.decode('utf-8'))

# Prepare and execute output
for park in listdata["data"]:
    print(park["fullName"])
# Out:
# Abraham Lincoln Birthplace National Historical Park
# Acadia National Park
# Adams National Historical Park
# African American Civil War Memorial
# African Burial Ground National Monument
# Agate Fossil Beds National Monument
# Ala Kahakai National Historic Trail
# Alagnak Wild River
# Alaska Public Lands
# Alcatraz Island
# Aleutian Islands World War II National Historic Area
# Alibates Flint Quarries National Monument
# Allegheny Portage Railroad National Historic Site
# Amache National Historic Site
# American Memorial Park
# Amistad National Recreation Area
# Anacostia Park
# Andersonville National Historic Site
# Andrew Johnson National Historic Site
# Aniakchak National Monument & Preserve
# Antietam National Battlefield
# Apostle Islands National Lakeshore
# Appalachian National Scenic Trail
# Appomattox Court House National Historical Park
# Arches National Park
# Arkansas Post National Memorial
# Arlington House, The Robert E. Lee Memorial
# ...

# %%
# Configure API request
# Note limit parameter is arbitrary value greater than total number of NPS sites
parks = []
listendpoint = "https://developer.nps.gov/api/v1/parks?limit=600"
req = urllib.request.Request(listendpoint,headers=HEADERS)

# Execute request and parse response
listresponse = urllib.request.urlopen(req).read()
listdata = json.loads(listresponse.decode('utf-8'))

# Prepare and execute output
for park in listdata["data"]:
    parks.append(park["fullName"])

# %%
parks
# Out:
# ['Abraham Lincoln Birthplace National Historical Park',
#  'Acadia National Park',
#  'Adams National Historical Park',
#  'African American Civil War Memorial',
#  'African Burial Ground National Monument',
#  'Agate Fossil Beds National Monument',
#  'Ala Kahakai National Historic Trail',
#  'Alagnak Wild River',
#  'Alaska Public Lands',
#  'Alcatraz Island',
#  'Aleutian Islands World War II National Historic Area',
#  'Alibates Flint Quarries National Monument',
#  'Allegheny Portage Railroad National Historic Site',
#  'Amache National Historic Site',
#  'American Memorial Park',
#  'Amistad National Recreation Area',
#  'Anacostia Park',
#  'Andersonville National Historic Site',
#  'Andrew Johnson National Historic Site',
#  'Aniakchak National Monument & Preserve',
#  'Antietam National Battlefield',
#  'Apostle Islands National Lakeshore',
#  'Appalachian National Scenic Trail',
#  'Appomattox Court House National Historical Park',
#  'Arches National Park',
# ...

# %%
parks_df = pd.DataFrame(parks)
parks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 471 entries, 0 to 470
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       471 non-null    object
# dtypes: object(1)
# memory usage: 3.8+ KB

# %% [markdown]
# import urllib.request, json
#
# # Configure API request
# # Note limit parameter is arbitrary value greater than total number of NPS sites
# parklist = "https://developer.nps.gov/api/v1/parks?limit=600"
# HEADERS = {"Authorization":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
# parklistreq = urllib.request.Request(parklist,headers=HEADERS)
#
# # Execute request and parse response
# parklistresponse = urllib.request.urlopen(req).read()
# data = json.loads(response.decode('utf-8'))
#
# # Prepare and execute output
# for park in data["data"]:
#     print(park["fullName"])

# %% [markdown]
#  Try and find a way to pull data from multiple parks

# %%
today = date.today()
print(today)
# Out:
# 2024-01-10

# %%
##titles of alerts
alertendpoint = "https://developer.nps.gov/api/v1/alerts?&stateCode=ME&limit=10&start=01-01-2024&end=01-09-2024"
HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
alertreq = urllib.request.Request(alertendpoint,headers=HEADERS)
alertresponse = urllib.request.urlopen(alertreq).read()
alertdata = json.loads(alertresponse.decode('utf-8'))
alertdata
for alert in alertdata["data"]:
    print(alert["title"])
# Out:
# CENTRAL VA – PARKING LOT CLOSURE– ROUTE 311/MCAFEE KNOB
# North Entrance and Loop Roads Closed for the Winter Season
# Logging traffic on Swift Brook Road
# Roosevelt Campobello International Park is located in Welshpool.
# Operating Hours & Seasons

# %%
alertendpoint = "https://developer.nps.gov/api/v1/alerts?&stateCode=ME&limit=10&start=01-01-2024&end=01-09-2024"
HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
alertreq = urllib.request.Request(alertendpoint,headers=HEADERS)
alertresponse = urllib.request.urlopen(alertreq).read()
alertdata = json.loads(alertresponse.decode('utf-8'))
alertdata
for alert in alertdata["data"]:
    print(alert["description"])
# Out:
# McAfee Knob/Route 311 parking area along the A.T. in Catawba will be closed Thursday, November 30. The lot is being closed to allow for the construction of a new pedestrian footbridge over Route 311.
# As of November 3, 2023, the North Entrance Road and the Katahdin View Loop Road are closed to wheeled vehicles for the winter season. Access by foot and bicycle is permitted.
# Yield to logging trucks on Swift Brook Road. There may be increased traffic between the Roberts Road junction and Sandbank Stream Campground due to logging on private land adjacent to the monument. Logging trucks ALWAYS have the right of way.
# Campobello Island is located in the province of New Brunswick, Canada. The physical address for the Visitor Centre is: 459 Route 774 Welshpool, New Brunswick, Canada E5E 1A4
# The park is normally open year-round during daylight hours. Some park facilities are closed during the winter.

# %%
##titles and descriptions of alerts
alertendpoint = "https://developer.nps.gov/api/v1/alerts?&stateCode=ME&limit=50&start=01-09-2024&end=01-09-2024"
HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
alertreq = urllib.request.Request(alertendpoint,headers=HEADERS)
alertresponse = urllib.request.urlopen(alertreq).read()
alertdata = json.loads(alertresponse.decode('utf-8'))
alertdata
for alert in alertdata["data"]:
    print(alert["title"])
    print(alert["description"])
# Out:
# CENTRAL VA – PARKING LOT CLOSURE– ROUTE 311/MCAFEE KNOB
# McAfee Knob/Route 311 parking area along the A.T. in Catawba will be closed Thursday, November 30. The lot is being closed to allow for the construction of a new pedestrian footbridge over Route 311.
# North Entrance and Loop Roads Closed for the Winter Season
# As of November 3, 2023, the North Entrance Road and the Katahdin View Loop Road are closed to wheeled vehicles for the winter season. Access by foot and bicycle is permitted.
# Logging traffic on Swift Brook Road
# Yield to logging trucks on Swift Brook Road. There may be increased traffic between the Roberts Road junction and Sandbank Stream Campground due to logging on private land adjacent to the monument. Logging trucks ALWAYS have the right of way.
# Roosevelt Campobello International Park is located in Welshpool.
# ...

# %%
def get_text():
    text = entry.get()
    label.config(text=f"You entered: {text}")

# %% [markdown]
# # Create a Tkinter window
# root = tk.Tk()
# root.title("Interactive Text Box")
#
# entry = tk.Entry(root, width=30)
# entry.pack()
#
# # Create a button to get the text from the entry widget
# button = tk.Button(root, text="Get Text", command=get_text)
# button.pack()
#
# # Create a label to display the entered text
# label = tk.Label(root, text="")
# label.pack()
#
# # Run the Tkinter main loop
# root.mainloop()

# %%
## Make a list of park codes, see if you can get it to iterate for each park. Get parkname, alert title
##titles of alerts given park code
palertendpoint = "https://developer.nps.gov/api/v1/alerts?&stateCode=ME&limit=50&start=01-09-2024&end=01-09-2024"
HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
palertreq = urllib.request.Request(palertendpoint,headers=HEADERS)
palertresponse = urllib.request.urlopen(palertreq).read()
palertdata = json.loads(palertresponse.decode('utf-8'))
palertdata
for alert in palertdata["data"]:
    print(alert["parkCode"])
    print(alert["title"])
    print(alert["description"])
# Out:
# appa
# CENTRAL VA – PARKING LOT CLOSURE– ROUTE 311/MCAFEE KNOB
# McAfee Knob/Route 311 parking area along the A.T. in Catawba will be closed Thursday, November 30. The lot is being closed to allow for the construction of a new pedestrian footbridge over Route 311.
# kaww
# North Entrance and Loop Roads Closed for the Winter Season
# As of November 3, 2023, the North Entrance Road and the Katahdin View Loop Road are closed to wheeled vehicles for the winter season. Access by foot and bicycle is permitted.
# kaww
# Logging traffic on Swift Brook Road
# Yield to logging trucks on Swift Brook Road. There may be increased traffic between the Roberts Road junction and Sandbank Stream Campground due to logging on private land adjacent to the monument. Logging trucks ALWAYS have the right of way.
# roca
# Roosevelt Campobello International Park is located in Welshpool.
# ...

# %%
## try pulling state codes from json and returning the full state names from a csv
states = pd.read_csv('../data/states.csv',encoding='utf-8')
states
# Out:
#              State State Code
# 0          Alabama         AL
# 1           Alaska         AK
# 2          Arizona         AZ
# 3         Arkansas         AR
# 4       California         CA
# 5         Colorado         CO
# 6      Connecticut         CT
# 7         Delaware         DE
# 8          Florida         FL
# 9          Georgia         GA
# 10          Hawaii         HI
# 11           Idaho         ID
# 12        Illinois         IL
# 13         Indiana         IN
# 14            Iowa         IA
# 15          Kansas         KS
# 16        Kentucky         KY
# 17       Louisiana         LA
# 18           Maine         ME
# 19         Montana         MT
# 20        Nebraska         NE
# 21          Nevada         NV
# 22   New Hampshire         NH
# 23      New Jersey         NJ
# 24      New Mexico         NM
# 25        New York         NY
# 26  North Carolina         NC
# 27    North Dakota         ND
# 28            Ohio         OH
# 29        Oklahoma         OK
# ...

# %%
states['State Code'] = states['State Code'].str.lower()

# %%
tstates = states['State Code'].values

# %%
tstates
# Out:
# array(['al', 'ak', 'az', 'ar', 'ca', 'co', 'ct', 'de', 'fl', 'ga', 'hi',
#        'id', 'il', 'in', 'ia', 'ks', 'ky', 'la', 'me', 'mt', 'ne', 'nv',
#        'nh', 'nj', 'nm', 'ny', 'nc', 'nd', 'oh', 'ok', 'or', 'md', 'ma',
#        'mi', 'mn', 'ms', 'mo', 'pa', 'ri', 'sc', 'sd', 'tn', 'tx', 'ut',
#        'vt', 'va', 'wa', 'wv', 'wi', 'wy'], dtype=object)

# %%
park_name = []
park_code = []

# %%
# Out:
#   Cell In[18], line 2
#     category2_values.append(entry.get('category2'))
#     ^
# IndentationError: unexpected indent

# %%
scendpoint = "https://developer.nps.gov/api/v1/parks?stateCode=TN"
HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
screq = urllib.request.Request(scendpoint,headers=HEADERS)
scresponse = urllib.request.urlopen(screq).read()
scdata = json.loads(scresponse.decode('utf-8'))
for park in scdata["data"]:
    park_name.append(park["fullName"])
    park_code.append(park["parkCode"])

# %%
park_code
# Out:
# ['anjo',
#  'appa',
#  'biso',
#  'chch',
#  'cuga',
#  'fodo',
#  'grsm',
#  'mapr',
#  'natt',
#  'natr',
#  'obed',
#  'ovvi',
#  'shil',
#  'stri',
#  'trte']

# %%
park_name
# Out:
# ['Andrew Johnson National Historic Site',
#  'Appalachian National Scenic Trail',
#  'Big South Fork National River & Recreation Area',
#  'Chickamauga & Chattanooga National Military Park',
#  'Cumberland Gap National Historical Park',
#  'Fort Donelson National Battlefield',
#  'Great Smoky Mountains National Park',
#  'Manhattan Project National Historical Park',
#  'Natchez Trace National Scenic Trail',
#  'Natchez Trace Parkway',
#  'Obed Wild & Scenic River',
#  'Overmountain Victory National Historic Trail',
#  'Shiloh National Military Park',
#  'Stones River National Battlefield',
#  'Trail Of Tears National Historic Trail']

# %%
statecodes = ['MA', 'TN']
b = [0,1]

# %%
tempendpoint = f"http://developer.nps.gov/api/v1/alerts?&stateCode={states['State Code']}"

# %%
for state in states['State Code']:
    print(state)
# Out:
# al
# ak
# az
# ar
# ca
# co
# ct
# de
# fl
# ga
# hi
# id
# il
# in
# ia
# ks
# ky
# la
# me
# mt
# ne
# nv
# nh
# nj
# nm
# ny
# nc
# nd
# oh
# ok
# or
# md
# ma
# mi
# mn
# ms
# mo
# pa
# ri
# sc
# sd
# tn
# tx
# ut
# vt
# va
# wa
# wv
# wi
# wy

# %%
ttstates = ",".join(tstates)
ttstates
# Out:
# 'al,ak,az,ar,ca,co,ct,de,fl,ga,hi,id,il,in,ia,ks,ky,la,me,mt,ne,nv,nh,nj,nm,ny,nc,nd,oh,ok,or,md,ma,mi,mn,ms,mo,pa,ri,sc,sd,tn,tx,ut,vt,va,wa,wv,wi,wy'

# %%
stendpoint = http://developer.nps.gov/api/v1/alerts?&stateCode=
HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
streq = urllib.request.Request(stendpoint,headers=HEADERS)
stresponse = urllib.request.urlopen(streq).read()
stdata = json.loads(scresponse.decode('utf-8'))
stdata
# Out:
#   Cell In[44], line 1
#     stendpoint = f'http://developer.nps.gov/api/v1/alerts?&stateCode={for state in states['State Code']:
#                                                                                                      ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
ttstates
# Out:
# 'al,ak,az,ar,ca,co,ct,de,fl,ga,hi,id,il,in,ia,ks,ky,la,me,mt,ne,nv,nh,nj,nm,ny,nc,nd,oh,ok,or,md,ma,mi,mn,ms,mo,pa,ri,sc,sd,tn,tx,ut,vt,va,wa,wv,wi,wy'

# %% [markdown]
# stendpoint = "https://developer.nps.gov/api/v1/parks?stateCode=" + states['State Code'].values
# HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
# streq = urllib.request.Request(stendpoint,headers=HEADERS)
# stresponse = urllib.request.urlopen(streq).read()
# stdata = json.loads(scresponse.decode('utf-8'))
# stdata

# %%
endpoint = f"/endpoint/{i}"

# %%
for statecod in ttstates:
    endpoint = f"/http://developer.nps.gov/api/v1/alerts?&stateCode={statecod}"
    HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
    streq = urllib.request.Request(stendpoint,headers=HEADERS)
    stresponse = urllib.request.urlopen(streq).read()
    stdata = json.loads(scresponse.decode('utf-8'))
    stdata
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# Cell In[80], line 5
#       3 HEADERS = {"X-Api-Key":"GgpNdjpDQeArMt2E2oQ7TVtXq8PpzKcYO4mHfMe7"}
#       4 streq = urllib.request.Request(stendpoint,headers=HEADERS)
# ----> 5 stresponse = urllib.request.urlopen(streq).read()
#       6 stdata = json.loads(scresponse.decode('utf-8'))
#       7 stdata
#
# File ~\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~\anaconda3\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
# ...

# %% [markdown]
# #####
